# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None 

# File to Load (Remember to Change These)
cdata = "city_data.csv"

# Read Purchasing File and store into Pandas data frame
cdata_df = pd.read_csv(cdata)

cdata_df
# Out:
#                   City    Lat     Lon  Max Temp  Humidity  Cloudiness  \
# 0            carnarvon -24.87  113.63     19.00        82          90
# 1            cape town -33.93   18.42      8.89        75           0
# 2                zemio   5.03   25.14     20.29        96          74
# 3                 hilo  19.73 -155.09     27.00        74          20
# 4           nikolskoye  59.70   30.79     15.56        77          86
# ..                 ...    ...     ...       ...       ...         ...
# 538              arica -18.48  -70.30     15.84        79         100
# 539       buenos aires -34.61  -58.38     11.00        71           0
# 540  troitsko-pechorsk  62.71   56.20     22.11        79         100
# 541              arvin  35.21 -118.83     32.00        27           1
# 542              kaoma -14.78   24.80      5.95        90           0
#
#      Wind Speed Country        Date
# 0          8.70      AU  1594961110
# 1          2.10      ZA  1594961158
# ...

# %%
cdata_html = cdata_df.to_html()
print(cdata_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lon</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>carnarvon</td>
#       <td>-24.87</td>
#       <td>113.63</td>
#       <td>19.00</td>
#       <td>82</td>
#       <td>90</td>
#       <td>8.70</td>
#       <td>AU</td>
#       <td>1594961110</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>cape town</td>
#       <td>-33.93</td>
#       <td>18.42</td>
#       <td>8.89</td>
#       <td>75</td>
#       <td>0</td>
#       <td>2.10</td>
#       <td>ZA</td>
#       <td>1594961158</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>zemio</td>
#       <td>5.03</td>
#       <td>25.14</td>
#       <td>20.29</td>
# ...
